# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torch.utils.data import Subset
import matplotlib.pyplot as plt
import numpy as np
import torchvision.utils as utils
from IPython.display import HTML
import time
from torchvision import models
import torch.nn.functional as F
from scipy import linalg

# %%
dataset = datasets.CIFAR10(root="/Users/suraj/Documents/DL/dataset/CIFAR10data", download=True,
                           transform=transforms.Compose([
                               transforms.Resize(64),
                               transforms.ToTensor(),
                               transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                           ]))

dataloader = torch.utils.data.DataLoader(dataset, batch_size=32,
                                         shuffle=True, num_workers=2)

device = torch.device("cuda")
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to /Users/suraj/Documents/DL/dataset/CIFAR10data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting /Users/suraj/Documents/DL/dataset/CIFAR10data/cifar-10-python.tar.gz to /Users/suraj/Documents/DL/dataset/CIFAR10data

# %%
real_batch = next(iter(dataloader))
plt.figure(figsize=(10,10))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(utils.make_grid(real_batch[0].to(device)[:64], padding=2, normalize=True).cpu(),(1,2,0)))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /var/folders/x1/3fzzpt8s0wb1z5zdd_z53mxr0000gn/T/ipykernel_71940/1403792162.py in <module>
#       3 plt.axis("off")
#       4 plt.title("Training Images")
# ----> 5 plt.imshow(np.transpose(utils.make_grid(real_batch[0].to(device)[:64], padding=2, normalize=True).cpu(),(1,2,0)))
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/cuda/__init__.py in _lazy_init()
#     219                 "multiprocessing, you must use the 'spawn' start method")
#     220         if not hasattr(torch._C, '_cuda_getDeviceCount'):
# --> 221             raise AssertionError("Torch not compiled with CUDA enabled")
#     222         if _cudart is None:
#     223             raise AssertionError(
#
# AssertionError: Torch not compiled with CUDA enabled

# %%
class Discriminator(nn.Module):
    def __init__(self, channels_img, features_d):
        super(Discriminator, self).__init__()
        self.disc = nn.Sequential(
            # input: N x channels_img x 64 x 64
            nn.Conv2d(
                channels_img, features_d, kernel_size=4, stride=2, padding=1
            ),
            nn.LeakyReLU(0.2),
            # _block(in_channels, out_channels, kernel_size, stride, padding)
            self._block(features_d, features_d * 2, 4, 2, 1),
            self._block(features_d * 2, features_d * 4, 4, 2, 1),
            self._block(features_d * 4, features_d * 8, 4, 2, 1),
            # After all _block img output is 4x4 (Conv2d below makes into 1x1)
            nn.Conv2d(features_d * 8, 1, kernel_size=4, stride=2, padding=0),
        )

    def _block(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.Conv2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                bias=False,
            ),
            nn.InstanceNorm2d(out_channels, affine=True),
            nn.LeakyReLU(0.2),
        )

    def forward(self, x):
        return self.disc(x)

# %%
class Generator(nn.Module):
    def __init__(self, channels_noise, channels_img, features_g):
        super(Generator, self).__init__()
        self.net = nn.Sequential(
            # Input: N x channels_noise x 1 x 1
            self._block(channels_noise, features_g * 16, 4, 1, 0),  # img: 4x4
            self._block(features_g * 16, features_g * 8, 4, 2, 1),  # img: 8x8
            self._block(features_g * 8, features_g * 4, 4, 2, 1),  # img: 16x16
            self._block(features_g * 4, features_g * 2, 4, 2, 1),  # img: 32x32
            nn.ConvTranspose2d(
                features_g * 2, channels_img, kernel_size=4, stride=2, padding=1
            ),
            # Output: N x channels_img x 64 x 64
            nn.Tanh(),
        )

    def _block(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.ConvTranspose2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                bias=False,
            ),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
        )

    def forward(self, x):
        return self.net(x)

# %%
def initialize_weights(model):
    # Initializes weights according to the DCGAN paper
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d, nn.BatchNorm2d)):
            nn.init.normal_(m.weight.data, 0.0, 0.02)

# %%
class InceptionV3(nn.Module):
    """Pretrained InceptionV3 network returning feature maps"""

    # Index of default block of inception to return,
    # corresponds to output of final average pooling
    DEFAULT_BLOCK_INDEX = 3

    # Maps feature dimensionality to their output blocks indices
    BLOCK_INDEX_BY_DIM = {
        64: 0,
        192: 1,
        768: 2,
        2048: 3
    }

    def __init__(self,
                 output_blocks=[DEFAULT_BLOCK_INDEX],
                 resize_input=True,
                 normalize_input=True,
                 requires_grad=False):
        
        super(InceptionV3, self).__init__()

        self.resize_input = resize_input
        self.normalize_input = normalize_input
        self.output_blocks = sorted(output_blocks)
        self.last_needed_block = max(output_blocks)

        assert self.last_needed_block <= 3, \
            'Last possible output block index is 3'

        self.blocks = nn.ModuleList()

        
        inception = models.inception_v3(pretrained=True)

        # Block 0: input to maxpool1
        block0 = [
            inception.Conv2d_1a_3x3,
            inception.Conv2d_2a_3x3,
            inception.Conv2d_2b_3x3,
            nn.MaxPool2d(kernel_size=3, stride=2)
        ]
        self.blocks.append(nn.Sequential(*block0))
        # Block 1: maxpool1 to maxpool2
        if self.last_needed_block >= 1:
            block1 = [
                inception.Conv2d_3b_1x1,
                inception.Conv2d_4a_3x3,
                nn.MaxPool2d(kernel_size=3, stride=2)
            ]
            self.blocks.append(nn.Sequential(*block1))

        # Block 2: maxpool2 to aux classifier
        if self.last_needed_block >= 2:
            block2 = [
                inception.Mixed_5b,
                inception.Mixed_5c,
                inception.Mixed_5d,
                inception.Mixed_6a,
                inception.Mixed_6b,
                inception.Mixed_6c,
                inception.Mixed_6d,
                inception.Mixed_6e,
            ]
            self.blocks.append(nn.Sequential(*block2))

        # Block 3: aux classifier to final avgpool
        if self.last_needed_block >= 3:
            block3 = [
                inception.Mixed_7a,
                inception.Mixed_7b,
                inception.Mixed_7c,
                nn.AdaptiveAvgPool2d(output_size=(1, 1))
            ]
            self.blocks.append(nn.Sequential(*block3))

        for param in self.parameters():
            param.requires_grad = requires_grad
    def forward(self, inp):
        outp = []
        x = inp

        if self.resize_input:
            x = F.interpolate(x,
                              size=(299, 299),
                              mode='bilinear',
                              align_corners=False)

        if self.normalize_input:
            x = 2 * x - 1  # Scale from range (0, 1) to range (-1, 1)

        for idx, block in enumerate(self.blocks):
            x = block(x)
            if idx in self.output_blocks:
                outp.append(x)

            if idx == self.last_needed_block:
                break

        return outp
    
block_idx = InceptionV3.BLOCK_INDEX_BY_DIM[2048]
model = InceptionV3([block_idx])
model=model.cuda()
# Out:
# /home/ralluri/.local/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/ralluri/.local/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
def calculate_activation_statistics(images, model, batch_size=128, dims=2048, cuda=False):
    model.eval()
    act=np.empty((len(images), dims))
    
    if cuda:
        batch=images.cuda()
    else:
        batch=images
    pred = model(batch)[0]
    if pred.size(2) != 1 or pred.size(3) != 1:
        pred = adaptive_avg_pool2d(pred, output_size=(1, 1))

    act= pred.cpu().data.numpy().reshape(pred.size(0), -1)
    
    mu = np.mean(act, axis=0)
    sigma = np.cov(act, rowvar=False)
    return mu, sigma

def calculate_frechet_distance(mu1, sigma1, mu2, sigma2, eps=1e-6):
    mu1 = np.atleast_1d(mu1)
    mu2 = np.atleast_1d(mu2)

    sigma1 = np.atleast_2d(sigma1)
    sigma2 = np.atleast_2d(sigma2)

    assert mu1.shape == mu2.shape, \
        'Training and test mean vectors have different lengths'
    assert sigma1.shape == sigma2.shape, \
        'Training and test covariances have different dimensions'

    diff = mu1 - mu2

    covmean, _ = linalg.sqrtm(sigma1.dot(sigma2), disp=False)
    if not np.isfinite(covmean).all():
        msg = ('fid calculation produces singular product; '
               'adding %s to diagonal of cov estimates') % eps
        print(msg)
        offset = np.eye(sigma1.shape[0]) * eps
        covmean = linalg.sqrtm((sigma1 + offset).dot(sigma2 + offset))

    
    if np.iscomplexobj(covmean):
        if not np.allclose(np.diagonal(covmean).imag, 0, atol=1e-3):
            m = np.max(np.abs(covmean.imag))
            raise ValueError('Imaginary component {}'.format(m))
        covmean = covmean.real

    tr_covmean = np.trace(covmean)

    return (diff.dot(diff) + np.trace(sigma1) +
            np.trace(sigma2) - 2 * tr_covmean)

def calculate_fretchet(images_real,images_fake,model):
    mu_1,std_1 = calculate_activation_statistics(images_real,model,cuda=True)
    mu_2,std_2 = calculate_activation_statistics(images_fake,model,cuda=True)
    fid_value = calculate_frechet_distance(mu_1, std_1, mu_2, std_2)
    return fid_value

# %%
lr = 5e-5
Z_DIM = 128
num_epochs = 50
WEIGHT_CLIP = 0.01

# %%
gen = Generator(Z_DIM, channels_img = 3, features_g = 64).to(device)
critic = Discriminator(channels_img = 3, features_d = 64).to(device)
initialize_weights(gen)
initialize_weights(critic)

# %%
opt_gen = optim.RMSprop(gen.parameters(), lr = lr)
opt_critic = optim.RMSprop(critic.parameters(), lr = lr)

fixed_noise = torch.randn(32, Z_DIM, 1, 1).to(device)
step = 0

gen.train()
critic.train()
# Out:
# Discriminator(
#   (disc): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (3): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (4): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (5): Conv2d(512, 1, kernel_size=(4, 4), stride=(2, 2))
#   )
# )

# %%
GenLoss = []
DiscLoss = []
img_list = []
fretchet_distances = []
iters = 0

for epoch in range(num_epochs):
    # Target labels not needed! <3 unsupervised
    for batch_idx, (data, _) in enumerate(dataloader):
        data = data.to(device)
        cur_batch_size = data.shape[0]

        # Train Critic: max E[critic(real)] - E[critic(fake)]
        for _ in range(5): # 5 critic iterations
            noise = torch.randn(cur_batch_size, Z_DIM, 1, 1).to(device)
            fake = gen(noise)
            critic_real = critic(data).reshape(-1)
            critic_fake = critic(fake).reshape(-1)
            loss_critic = -(torch.mean(critic_real) - torch.mean(critic_fake))
            critic.zero_grad()
            loss_critic.backward(retain_graph=True)
            opt_critic.step()

            # clip critic weights between -0.01, 0.01
            for p in critic.parameters():
                p.data.clamp_(-WEIGHT_CLIP, WEIGHT_CLIP)

        # Train Generator: max E[critic(gen_fake)] <-> min -E[critic(gen_fake)]
        gen_fake = critic(fake).reshape(-1)
        loss_gen = -torch.mean(gen_fake)
        gen.zero_grad()
        loss_gen.backward()
        opt_gen.step()

        # Print losses occasionally
        if batch_idx % 1000 == 0:
            print(
                f"Epoch [{epoch}/{num_epochs}] Batch {batch_idx}/{len(dataloader)} \
                  Loss Discriminator: {loss_critic:.3f}, loss Generator: {loss_gen:.3f}"
            )
        #saving the losses for every 100 batch
        GenLoss.append(loss_gen.detach().cpu())
        DiscLoss.append(loss_critic.detach().cpu())
        
        # Check how the generator is doing by saving G's output on fixed_noise
        if (iters % 500 == 0) or ((epoch == num_epochs) and (batch_idx == len(dataloader)-1)):
            with torch.no_grad():
                fake = gen(fixed_noise).detach().cpu()
            img_list.append(utils.make_grid(fake, padding=2, normalize=True))
            
        iters += 1
    fretchet_dist = calculate_fretchet(data, fake, model)
    fretchet_distances.append(fretchet_dist)
    print('Fretchet Distance: ', fretchet_dist)
# Out:
# Epoch [0/50] Batch 0/1563                   Loss Discriminator: -0.018, loss Generator: 0.007
# Epoch [0/50] Batch 1000/1563                   Loss Discriminator: -1.343, loss Generator: 0.689
# Fretchet Distance:  373.23423587802915
# Epoch [1/50] Batch 0/1563                   Loss Discriminator: -1.148, loss Generator: 0.610
# Epoch [1/50] Batch 1000/1563                   Loss Discriminator: -1.034, loss Generator: 0.531
# Fretchet Distance:  307.34225106492227
# Epoch [2/50] Batch 0/1563                   Loss Discriminator: -0.944, loss Generator: 0.369
# Epoch [2/50] Batch 1000/1563                   Loss Discriminator: -0.961, loss Generator: 0.395
# Fretchet Distance:  317.45395547278537
# Epoch [3/50] Batch 0/1563                   Loss Discriminator: -0.988, loss Generator: 0.388
# Epoch [3/50] Batch 1000/1563                   Loss Discriminator: -0.946, loss Generator: 0.478
# Fretchet Distance:  291.3065946772771
# Epoch [4/50] Batch 0/1563                   Loss Discriminator: -0.885, loss Generator: 0.403
# Epoch [4/50] Batch 1000/1563                   Loss Discriminator: -0.712, loss Generator: 0.305
# Fretchet Distance:  280.2170168427455
# Epoch [5/50] Batch 0/1563                   Loss Discriminator: -0.774, loss Generator: 0.567
# Epoch [5/50] Batch 1000/1563                   Loss Discriminator: -0.715, loss Generator: 0.533
# Fretchet Distance:  314.0539139588859
# Epoch [6/50] Batch 0/1563                   Loss Discriminator: -0.745, loss Generator: 0.387
# Epoch [6/50] Batch 1000/1563                   Loss Discriminator: -0.501, loss Generator: 0.543
# Fretchet Distance:  275.5479293036142
# Epoch [7/50] Batch 0/1563                   Loss Discriminator: -0.653, loss Generator: 0.165
# Epoch [7/50] Batch 1000/1563                   Loss Discriminator: -0.568, loss Generator: 0.081
# Fretchet Distance:  266.9929986781054
# Epoch [8/50] Batch 0/1563                   Loss Discriminator: -0.699, loss Generator: 0.139
# Epoch [8/50] Batch 1000/1563                   Loss Discriminator: -0.537, loss Generator: 0.558
# Fretchet Distance:  286.63856868298154
# Epoch [9/50] Batch 0/1563                   Loss Discriminator: -0.607, loss Generator: 0.546
# Epoch [9/50] Batch 1000/1563                   Loss Discriminator: -0.508, loss Generator: 0.538
# Fretchet Distance:  260.38811505675505
# Epoch [10/50] Batch 0/1563                   Loss Discriminator: -0.565, loss Generator: 0.551
# Epoch [10/50] Batch 1000/1563                   Loss Discriminator: -0.619, loss Generator: 0.379
# Fretchet Distance:  274.74719911696144
# Epoch [11/50] Batch 0/1563                   Loss Discriminator: -0.454, loss Generator: 0.466
# Epoch [11/50] Batch 1000/1563                   Loss Discriminator: -0.536, loss Generator: 0.087
# Fretchet Distance:  314.9413214654195
# Epoch [12/50] Batch 0/1563                   Loss Discriminator: -0.431, loss Generator: 0.534
# Epoch [12/50] Batch 1000/1563                   Loss Discriminator: -0.591, loss Generator: 0.550
# Fretchet Distance:  279.42600973496627
# Epoch [13/50] Batch 0/1563                   Loss Discriminator: -0.459, loss Generator: 0.524
# Epoch [13/50] Batch 1000/1563                   Loss Discriminator: -0.507, loss Generator: 0.132
# Fretchet Distance:  242.95854581358947
# Epoch [14/50] Batch 0/1563                   Loss Discriminator: -0.462, loss Generator: 0.498
# Epoch [14/50] Batch 1000/1563                   Loss Discriminator: -0.469, loss Generator: -0.086
# Fretchet Distance:  272.7895895823857
# Epoch [15/50] Batch 0/1563                   Loss Discriminator: -0.523, loss Generator: 0.361
# Epoch [15/50] Batch 1000/1563                   Loss Discriminator: -0.536, loss Generator: -0.098
# Fretchet Distance:  266.70732847545435
# Epoch [16/50] Batch 0/1563                   Loss Discriminator: -0.412, loss Generator: 0.038
# Epoch [16/50] Batch 1000/1563                   Loss Discriminator: -0.510, loss Generator: 0.201
# Fretchet Distance:  318.25316897945936
# Epoch [17/50] Batch 0/1563                   Loss Discriminator: -0.523, loss Generator: 0.427
# Epoch [17/50] Batch 1000/1563                   Loss Discriminator: -0.472, loss Generator: 0.546
# Fretchet Distance:  284.4590364388972
# Epoch [18/50] Batch 0/1563                   Loss Discriminator: -0.461, loss Generator: 0.312
# Epoch [18/50] Batch 1000/1563                   Loss Discriminator: -0.494, loss Generator: 0.517
# Fretchet Distance:  287.0681999248584
# Epoch [19/50] Batch 0/1563                   Loss Discriminator: -0.531, loss Generator: 0.450
# Epoch [19/50] Batch 1000/1563                   Loss Discriminator: -0.571, loss Generator: 0.571
# Fretchet Distance:  278.7659557145963
# Epoch [20/50] Batch 0/1563                   Loss Discriminator: -0.485, loss Generator: -0.062
# Epoch [20/50] Batch 1000/1563                   Loss Discriminator: -0.541, loss Generator: 0.301
# Fretchet Distance:  286.3071215226273
# Epoch [21/50] Batch 0/1563                   Loss Discriminator: -0.540, loss Generator: 0.279
# Epoch [21/50] Batch 1000/1563                   Loss Discriminator: -0.545, loss Generator: 0.508
# Fretchet Distance:  289.9595332609597
# Epoch [22/50] Batch 0/1563                   Loss Discriminator: -0.457, loss Generator: 0.360
# Epoch [22/50] Batch 1000/1563                   Loss Discriminator: -0.482, loss Generator: 0.350
# Fretchet Distance:  261.3506054766543
# Epoch [23/50] Batch 0/1563                   Loss Discriminator: -0.377, loss Generator: -0.068
# Epoch [23/50] Batch 1000/1563                   Loss Discriminator: -0.507, loss Generator: 0.524
# Fretchet Distance:  256.6684617722881
# Epoch [24/50] Batch 0/1563                   Loss Discriminator: -0.392, loss Generator: 0.334
# Epoch [24/50] Batch 1000/1563                   Loss Discriminator: -0.387, loss Generator: -0.072
# Fretchet Distance:  272.3197856999844
# Epoch [25/50] Batch 0/1563                   Loss Discriminator: -0.481, loss Generator: 0.170
# Epoch [25/50] Batch 1000/1563                   Loss Discriminator: -0.518, loss Generator: 0.310
# Fretchet Distance:  283.696807474174
# Epoch [26/50] Batch 0/1563                   Loss Discriminator: -0.456, loss Generator: 0.366
# Epoch [26/50] Batch 1000/1563                   Loss Discriminator: -0.492, loss Generator: 0.283
# Fretchet Distance:  271.32173841487065
# Epoch [27/50] Batch 0/1563                   Loss Discriminator: -0.451, loss Generator: 0.329
# Epoch [27/50] Batch 1000/1563                   Loss Discriminator: -0.543, loss Generator: 0.432
# Fretchet Distance:  268.4878137441822
# Epoch [28/50] Batch 0/1563                   Loss Discriminator: -0.420, loss Generator: 0.377
# Epoch [28/50] Batch 1000/1563                   Loss Discriminator: -0.399, loss Generator: 0.039
# Fretchet Distance:  276.3983589498673
# Epoch [29/50] Batch 0/1563                   Loss Discriminator: -0.403, loss Generator: 0.060
# Epoch [29/50] Batch 1000/1563                   Loss Discriminator: -0.380, loss Generator: 0.483
# Fretchet Distance:  270.2128469508357
# Epoch [30/50] Batch 0/1563                   Loss Discriminator: -0.380, loss Generator: 0.319
# Epoch [30/50] Batch 1000/1563                   Loss Discriminator: -0.305, loss Generator: 0.033
# Fretchet Distance:  283.8400947813212
# Epoch [31/50] Batch 0/1563                   Loss Discriminator: -0.386, loss Generator: 0.297
# Epoch [31/50] Batch 1000/1563                   Loss Discriminator: -0.369, loss Generator: 0.130
# Fretchet Distance:  275.6436043025785
# Epoch [32/50] Batch 0/1563                   Loss Discriminator: -0.368, loss Generator: 0.419
# Epoch [32/50] Batch 1000/1563                   Loss Discriminator: -0.420, loss Generator: 0.376
# Fretchet Distance:  291.51756982254005
# Epoch [33/50] Batch 0/1563                   Loss Discriminator: -0.451, loss Generator: 0.248
# Epoch [33/50] Batch 1000/1563                   Loss Discriminator: -0.369, loss Generator: -0.222
# Fretchet Distance:  268.3561132290965
# Epoch [34/50] Batch 0/1563                   Loss Discriminator: -0.484, loss Generator: 0.319
# Epoch [34/50] Batch 1000/1563                   Loss Discriminator: -0.396, loss Generator: 0.473
# Fretchet Distance:  284.21527632823825
# Epoch [35/50] Batch 0/1563                   Loss Discriminator: -0.412, loss Generator: 0.495
# Epoch [35/50] Batch 1000/1563                   Loss Discriminator: -0.387, loss Generator: -0.181
# Fretchet Distance:  278.38716329425665
# Epoch [36/50] Batch 0/1563                   Loss Discriminator: -0.312, loss Generator: 0.182
# Epoch [36/50] Batch 1000/1563                   Loss Discriminator: -0.442, loss Generator: 0.269
# Fretchet Distance:  279.14692326325894
# Epoch [37/50] Batch 0/1563                   Loss Discriminator: -0.507, loss Generator: 0.425
# Epoch [37/50] Batch 1000/1563                   Loss Discriminator: -0.377, loss Generator: 0.511
# Fretchet Distance:  276.9115703887312
# Epoch [38/50] Batch 0/1563                   Loss Discriminator: -0.336, loss Generator: 0.355
# Epoch [38/50] Batch 1000/1563                   Loss Discriminator: -0.422, loss Generator: 0.210
# Fretchet Distance:  290.2228533561953
# Epoch [39/50] Batch 0/1563                   Loss Discriminator: -0.374, loss Generator: -0.069
# Epoch [39/50] Batch 1000/1563                   Loss Discriminator: -0.402, loss Generator: 0.343
# Fretchet Distance:  286.2058278118172
# Epoch [40/50] Batch 0/1563                   Loss Discriminator: -0.368, loss Generator: 0.136
# Epoch [40/50] Batch 1000/1563                   Loss Discriminator: -0.428, loss Generator: 0.471
# Fretchet Distance:  269.18052634461844
# Epoch [41/50] Batch 0/1563                   Loss Discriminator: -0.451, loss Generator: 0.276
# Epoch [41/50] Batch 1000/1563                   Loss Discriminator: -0.373, loss Generator: 0.382
# Fretchet Distance:  269.8759711366399
# Epoch [42/50] Batch 0/1563                   Loss Discriminator: -0.383, loss Generator: 0.234
# Epoch [42/50] Batch 1000/1563                   Loss Discriminator: -0.394, loss Generator: 0.235
# Fretchet Distance:  291.0921140137974
# Epoch [43/50] Batch 0/1563                   Loss Discriminator: -0.282, loss Generator: 0.187
# Epoch [43/50] Batch 1000/1563                   Loss Discriminator: -0.252, loss Generator: 0.217
# Fretchet Distance:  262.45249850803236
# Epoch [44/50] Batch 0/1563                   Loss Discriminator: -0.149, loss Generator: 0.075
# Epoch [44/50] Batch 1000/1563                   Loss Discriminator: -0.297, loss Generator: 0.178
# Fretchet Distance:  282.4433406897218
# Epoch [45/50] Batch 0/1563                   Loss Discriminator: -0.119, loss Generator: 0.110
# Epoch [45/50] Batch 1000/1563                   Loss Discriminator: -0.139, loss Generator: 0.183
# Fretchet Distance:  287.3142653611524
# Epoch [46/50] Batch 0/1563                   Loss Discriminator: -0.272, loss Generator: 0.168
# Epoch [46/50] Batch 1000/1563                   Loss Discriminator: -0.207, loss Generator: 0.156
# Fretchet Distance:  289.12415627885196
# Epoch [47/50] Batch 0/1563                   Loss Discriminator: -0.103, loss Generator: 0.008
# Epoch [47/50] Batch 1000/1563                   Loss Discriminator: -0.101, loss Generator: 0.087
# Fretchet Distance:  262.5197640582519
# Epoch [48/50] Batch 0/1563                   Loss Discriminator: -0.099, loss Generator: 0.046
# Epoch [48/50] Batch 1000/1563                   Loss Discriminator: -0.352, loss Generator: 0.229
# Fretchet Distance:  294.9967369820706
# Epoch [49/50] Batch 0/1563                   Loss Discriminator: -0.114, loss Generator: 0.111
# Epoch [49/50] Batch 1000/1563                   Loss Discriminator: -0.232, loss Generator: 0.160
# Fretchet Distance:  284.4517743372877

# %%
plt.figure(figsize=(10,5))
plt.title("Generator and Discriminator Loss During Training")
plt.plot(GenLoss,label="Gen")
plt.plot(DiscLoss,label="Disc")
plt.xlabel("iterations")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,15))
plt.subplot(1,2,1)
plt.axis("off")
plt.title("Real Images")
plt.imshow(np.transpose(utils.make_grid(real_batch[0].to(device)[:64], padding=5, normalize=True).cpu(),(1,2,0)))

# %%
import pickle
with open('fd_wgan.pickle', 'wb') as f:
    pickle.dump(fretchet_distances, f)

# %%
import pickle
with open('fd_wgan.pickle', 'wb') as f:
    pickle.dump(fretchet_distances, f)
