# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torch.utils.data import Subset
import matplotlib.pyplot as plt
import numpy as np
import torchvision.utils as utils
from IPython.display import HTML
import time
from torchvision import models
import torch.nn.functional as F
from scipy import linalg

# %%
dataset = datasets.CIFAR10(root="/home/skhamka/Deep-Learning/Homework3/dataset/CIFAR10data", download=False,
                           transform=transforms.Compose([
                               transforms.Resize(64),
                               transforms.ToTensor(),
                               transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                           ]))

dataloader = torch.utils.data.DataLoader(dataset, batch_size=32,
                                         shuffle=True, num_workers=2)

device = torch.device("cuda")

# %%
real_batch = next(iter(dataloader))
plt.figure(figsize=(10,10))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(utils.make_grid(real_batch[0].to(device)[:64], padding=2, normalize=True).cpu(),(1,2,0)))

# %%
class Discriminator(nn.Module):
    def __init__(self, channels_img, features_d):
        super(Discriminator, self).__init__()
        self.disc = nn.Sequential(
            # input: N x channels_img x 64 x 64
            nn.Conv2d(
                channels_img, features_d, kernel_size=4, stride=2, padding=1
            ),
            nn.LeakyReLU(0.2),
            # _block(in_channels, out_channels, kernel_size, stride, padding)
            self.Dnet(features_d, features_d * 2, 4, 2, 1),
            self.Dnet(features_d * 2, features_d * 4, 4, 2, 1),
            self.Dnet(features_d * 4, features_d * 8, 4, 2, 1),
            nn.Conv2d(features_d * 8, 1, kernel_size=4, stride=2, padding=0),
            nn.Sigmoid(),
        )

    def Dnet(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.Conv2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                bias=False,
            ),
            nn.LeakyReLU(0.2),
        )

    def forward(self, x):
        return self.disc(x)

# %%
class Generator(nn.Module):
    def __init__(self, channels_noise, channels_img, features_g):
        super(Generator, self).__init__()
        self.net = nn.Sequential(
            self.Gnet(channels_noise, features_g * 16, 4, 1, 0),
            self.Gnet(features_g * 16, features_g * 8, 4, 2, 1),
            self.Gnet(features_g * 8, features_g * 4, 4, 2, 1),
            self.Gnet(features_g * 4, features_g * 2, 4, 2, 1),
            nn.ConvTranspose2d(
                features_g * 2, channels_img, kernel_size=4, stride=2, padding=1
            ),
            nn.Tanh(),
        )

    def Gnet(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.ConvTranspose2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                bias=False,
            ),
            nn.BatchNorm2d(out_channels,momentum=0.9),
            nn.ReLU(),
        )

    def forward(self, x):
        return self.net(x)

# %%
def init_weight(model):
    # Initialize weights according to the DCGAN paper
    for i in model.modules():
        if isinstance(i, (nn.Conv2d, nn.ConvTranspose2d, nn.BatchNorm2d)):
            nn.init.normal_(i.weight.data, 0.0, 0.02)

# %%
gen = Generator(channels_noise = 100, channels_img = 3, features_g = 64).to(device)
disc = Discriminator(channels_img = 3, features_d = 64).to(device)
init_weight(gen)
init_weight(disc)
lr = 2e-4

# %%
optimGenerator = optim.Adam(gen.parameters(), lr=lr, betas=(0.5, 0.999))
optimDiscriminator = optim.Adam(disc.parameters(), lr=lr, betas=(0.5, 0.999))
criterion = nn.BCELoss()
fixed_noise = torch.randn(32, 100, 1, 1).to(device)
step = 0

# %%
class Inception_version3(nn.Module):
    # Index of default block of inception to return,
    # corresponds to output of final average pooling
    DEFAULT_BLOCK_INDEX = 3

    # Maps feature dimensionality to their output blocks indices
    BLOCK_INDEX_BY_DIM = {
        64: 0,
        192: 1,
        768: 2,
        2048: 3
    }

    def __init__(self,
                 output_blocks=[DEFAULT_BLOCK_INDEX],
                 resize_input=True,
                 normalize_input=True,
                 requires_grad=False):
        
        super(Inception_version3, self).__init__()

        self.resize_input = resize_input
        self.normalize_input = normalize_input
        self.output_blocks = sorted(output_blocks)
        self.last_needed_block = max(output_blocks)

        assert self.last_needed_block <= 3, \
            'Last possible output block index is 3'

        self.blocks = nn.ModuleList()

        
        inception = models.inception_v3(pretrained=True)

        block0 = [
            inception.Conv2d_1a_3x3,
            inception.Conv2d_2a_3x3,
            inception.Conv2d_2b_3x3,
            nn.MaxPool2d(kernel_size=3, stride=2)
        ]
        self.blocks.append(nn.Sequential(*block0))
        # Block 1: maxpool1 to maxpool2
        if self.last_needed_block >= 1:
            block1 = [
                inception.Conv2d_3b_1x1,
                inception.Conv2d_4a_3x3,
                nn.MaxPool2d(kernel_size=3, stride=2)
            ]
            self.blocks.append(nn.Sequential(*block1))

        if self.last_needed_block >= 2:
            block2 = [
                inception.Mixed_5b,
                inception.Mixed_5c,
                inception.Mixed_5d,
                inception.Mixed_6a,
                inception.Mixed_6b,
                inception.Mixed_6c,
                inception.Mixed_6d,
                inception.Mixed_6e,
            ]
            self.blocks.append(nn.Sequential(*block2))
 
        if self.last_needed_block >= 3:
            block3 = [
                inception.Mixed_7a,
                inception.Mixed_7b,
                inception.Mixed_7c,
                nn.AdaptiveAvgPool2d(output_size=(1, 1))
            ]
            self.blocks.append(nn.Sequential(*block3))

        for param in self.parameters():
            param.requires_grad = requires_grad

    def forward(self, inp):
        outp = []
        x = inp

        if self.resize_input:
            x = F.interpolate(x,
                              size=(299, 299),
                              mode='bilinear',
                              align_corners=False)

        if self.normalize_input:
            x = 2 * x - 1  # Scale from range (0, 1) to range (-1, 1)

        for idx, block in enumerate(self.blocks):
            x = block(x)
            if idx in self.output_blocks:
                outp.append(x)

            if idx == self.last_needed_block:
                break

        return outp
    
block_idx = Inception_version3.BLOCK_INDEX_BY_DIM[2048]
model = Inception_version3([block_idx])
model=model.cuda()
# Out:
# /home/ralluri/.local/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/ralluri/.local/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
def cal_activation_statistics(images, model, batch_size=128, dims=2048, cuda=False):
    model.eval()
    act=np.empty((len(images), dims))
    
    if cuda:
        batch=images.cuda()
    else:
        batch=images
    pred = model(batch)[0]
    if pred.size(2) != 1 or pred.size(3) != 1:
        pred = adaptive_avg_pool2d(pred, output_size=(1, 1))

    act= pred.cpu().data.numpy().reshape(pred.size(0), -1)
    
    mu = np.mean(act, axis=0)
    sigma = np.cov(act, rowvar=False)
    return mu, sigma

def cal_frechet_distance(mu1, sigma1, mu2, sigma2, eps=1e-6):
    mu1 = np.atleast_1d(mu1)
    mu2 = np.atleast_1d(mu2)

    sigma1 = np.atleast_2d(sigma1)
    sigma2 = np.atleast_2d(sigma2)

    assert mu1.shape == mu2.shape, \
        'Training and test mean vectors have different lengths'
    assert sigma1.shape == sigma2.shape, \
        'Training and test covariances have different dimensions'

    diff = mu1 - mu2

    
    covmean, _ = linalg.sqrtm(sigma1.dot(sigma2), disp=False)
    if not np.isfinite(covmean).all():
        msg = ('fid calculation produces singular product; '
               'adding %s to diagonal of cov estimates') % eps
        print(msg)
        offset = np.eye(sigma1.shape[0]) * eps
        covmean = linalg.sqrtm((sigma1 + offset).dot(sigma2 + offset))

    
    if np.iscomplexobj(covmean):
        if not np.allclose(np.diagonal(covmean).imag, 0, atol=1e-3):
            m = np.max(np.abs(covmean.imag))
            raise ValueError('Imaginary component {}'.format(m))
        covmean = covmean.real

    tr_covmean = np.trace(covmean)

    return (diff.dot(diff) + np.trace(sigma1) +
            np.trace(sigma2) - 2 * tr_covmean)

def calculate_fretchet(images_real,images_fake,model):
    mu_1,std_1 = cal_activation_statistics(images_real,model,cuda=True)
    mu_2,std_2 = cal_activation_statistics(images_fake,model,cuda=True)
    fid_value = cal_frechet_distance(mu_1, std_1, mu_2, std_2)
    return fid_value

# %%
gen.train()
disc.train()
# Out:
# Discriminator(
#   (disc): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (3): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (4): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (5): Conv2d(512, 1, kernel_size=(4, 4), stride=(2, 2))
#     (6): Sigmoid()
#   )
# )

# %%
#training block
gen_loss = []
disc_loss = []
img_list = []
fretchet_distances = []
iteration = 0

time_start = time.time()
num_epochs = 50

for epoch in range(num_epochs):
    epoch = epoch+1

    for batch_idx, data in enumerate(dataloader,0):
        #training with real batch
        real = data[0].to(device)
        noise = torch.randn(128, 100, 1, 1).to(device)
        fake = gen(noise) #genrator img data

        ### Train Discriminator: max log(D(x)) + log(1 - D(G(z)))
        disc_real = disc(real).reshape(-1)
        loss_disc_real = criterion(disc_real, torch.ones_like(disc_real))
        disc_fake = disc(fake.detach()).reshape(-1)
        loss_disc_fake = criterion(disc_fake, torch.zeros_like(disc_fake))
        loss_disc = (loss_disc_real + loss_disc_fake) / 2
        disc.zero_grad()
        loss_disc.backward()
        optimDiscriminator.step()

        ### Train Generator: min log(1 - D(G(z))) <-> max log(D(G(z))
        output = disc(fake).reshape(-1)
        loss_gen = criterion(output, torch.ones_like(output))
        gen.zero_grad()
        loss_gen.backward()
        optimGenerator.step()

        # Print losses occasionally and print to tensorboard
        if batch_idx % 1000 == 0:
            print(
                f"Epoch [{epoch}/{num_epochs}] Batch {batch_idx}/{len(dataloader)} \
                  Loss Discriminator: {loss_disc:.3f}, loss Generator: {loss_gen:.3f}"
            )
        #saving the losses for every 100 batch
        gen_loss.append(loss_gen.detach().cpu())
        disc_loss.append(loss_disc.detach().cpu())
        
        
        # Check how the generator is doing by saving G's output on fixed_noise
        if (iteration % 500 == 0) or ((epoch == num_epochs) and (batch_idx == len(dataloader)-1)):
            with torch.no_grad():
                fake = gen(fixed_noise).detach().cpu()
            img_list.append(utils.make_grid(fake, padding=2, normalize=True))
            
        iteration += 1
    fretchet_dist = calculate_fretchet(real, fake, model)
    print('Fretchet Distance: ', fretchet_dist)
    fretchet_distances.append(fretchet_dist)
    
time_end = time.time()
print('elapsed time：%.2f s.'%(time_end-time_start))
# Out:
# Epoch [1/50] Batch 0/1563                   Loss Discriminator: 0.695, loss Generator: 0.705
# Epoch [1/50] Batch 1000/1563                   Loss Discriminator: 0.575, loss Generator: 1.223
# Fretchet Distance:  367.53639523002425
# Epoch [2/50] Batch 0/1563                   Loss Discriminator: 0.762, loss Generator: 1.486
# Epoch [2/50] Batch 1000/1563                   Loss Discriminator: 0.607, loss Generator: 1.036
# Fretchet Distance:  365.08790246634004
# Epoch [3/50] Batch 0/1563                   Loss Discriminator: 0.713, loss Generator: 1.236
# Epoch [3/50] Batch 1000/1563                   Loss Discriminator: 0.632, loss Generator: 0.924
# Fretchet Distance:  274.88886778007657
# Epoch [4/50] Batch 0/1563                   Loss Discriminator: 0.734, loss Generator: 1.032
# Epoch [4/50] Batch 1000/1563                   Loss Discriminator: 0.626, loss Generator: 0.793
# Fretchet Distance:  263.98189256255023
# Epoch [5/50] Batch 0/1563                   Loss Discriminator: 0.670, loss Generator: 0.720
# Epoch [5/50] Batch 1000/1563                   Loss Discriminator: 0.599, loss Generator: 1.035
# Fretchet Distance:  253.49375893397286
# Epoch [6/50] Batch 0/1563                   Loss Discriminator: 0.648, loss Generator: 0.817
# Epoch [6/50] Batch 1000/1563                   Loss Discriminator: 0.624, loss Generator: 0.811
# Fretchet Distance:  277.18507913762744
# Epoch [7/50] Batch 0/1563                   Loss Discriminator: 0.625, loss Generator: 1.084
# Epoch [7/50] Batch 1000/1563                   Loss Discriminator: 0.657, loss Generator: 0.775
# Fretchet Distance:  264.93657392056537
# Epoch [8/50] Batch 0/1563                   Loss Discriminator: 0.586, loss Generator: 0.812
# Epoch [8/50] Batch 1000/1563                   Loss Discriminator: 0.658, loss Generator: 1.009
# Fretchet Distance:  256.4789724998758
# Epoch [9/50] Batch 0/1563                   Loss Discriminator: 0.623, loss Generator: 0.939
# Epoch [9/50] Batch 1000/1563                   Loss Discriminator: 0.642, loss Generator: 0.766
# Fretchet Distance:  248.48100086400342
# Epoch [10/50] Batch 0/1563                   Loss Discriminator: 0.549, loss Generator: 1.118
# Epoch [10/50] Batch 1000/1563                   Loss Discriminator: 0.694, loss Generator: 1.428
# Fretchet Distance:  274.8592291541938
# Epoch [11/50] Batch 0/1563                   Loss Discriminator: 0.641, loss Generator: 0.876
# Epoch [11/50] Batch 1000/1563                   Loss Discriminator: 0.557, loss Generator: 0.935
# Fretchet Distance:  264.08026157714846
# Epoch [12/50] Batch 0/1563                   Loss Discriminator: 0.695, loss Generator: 0.945
# Epoch [12/50] Batch 1000/1563                   Loss Discriminator: 0.591, loss Generator: 1.089
# Fretchet Distance:  244.10988930053213
# Epoch [13/50] Batch 0/1563                   Loss Discriminator: 0.586, loss Generator: 0.973
# Epoch [13/50] Batch 1000/1563                   Loss Discriminator: 0.550, loss Generator: 1.068
# Fretchet Distance:  256.08743301465614
# Epoch [14/50] Batch 0/1563                   Loss Discriminator: 0.625, loss Generator: 0.834
# Epoch [14/50] Batch 1000/1563                   Loss Discriminator: 0.571, loss Generator: 1.075
# Fretchet Distance:  244.3005180566463
# Epoch [15/50] Batch 0/1563                   Loss Discriminator: 0.564, loss Generator: 1.051
# Epoch [15/50] Batch 1000/1563                   Loss Discriminator: 0.555, loss Generator: 1.241
# Fretchet Distance:  265.18699339934466
# Epoch [16/50] Batch 0/1563                   Loss Discriminator: 0.529, loss Generator: 0.836
# Epoch [16/50] Batch 1000/1563                   Loss Discriminator: 0.598, loss Generator: 1.069
# Fretchet Distance:  259.41387411574163
# Epoch [17/50] Batch 0/1563                   Loss Discriminator: 0.582, loss Generator: 1.082
# Epoch [17/50] Batch 1000/1563                   Loss Discriminator: 0.640, loss Generator: 1.031
# Fretchet Distance:  254.6333874521175
# Epoch [18/50] Batch 0/1563                   Loss Discriminator: 0.448, loss Generator: 1.321
# Epoch [18/50] Batch 1000/1563                   Loss Discriminator: 0.566, loss Generator: 1.389
# Fretchet Distance:  262.6835512705767
# Epoch [19/50] Batch 0/1563                   Loss Discriminator: 0.523, loss Generator: 1.443
# Epoch [19/50] Batch 1000/1563                   Loss Discriminator: 0.559, loss Generator: 0.994
# Fretchet Distance:  257.09361358858973
# Epoch [20/50] Batch 0/1563                   Loss Discriminator: 0.460, loss Generator: 1.345
# Epoch [20/50] Batch 1000/1563                   Loss Discriminator: 0.503, loss Generator: 1.390
# Fretchet Distance:  266.572798494989
# Epoch [21/50] Batch 0/1563                   Loss Discriminator: 0.454, loss Generator: 1.226
# Epoch [21/50] Batch 1000/1563                   Loss Discriminator: 0.543, loss Generator: 1.134
# Fretchet Distance:  236.09135965022952
# Epoch [22/50] Batch 0/1563                   Loss Discriminator: 0.481, loss Generator: 1.333
# Epoch [22/50] Batch 1000/1563                   Loss Discriminator: 0.470, loss Generator: 1.528
# Fretchet Distance:  242.72625331040763
# Epoch [23/50] Batch 0/1563                   Loss Discriminator: 0.596, loss Generator: 1.325
# Epoch [23/50] Batch 1000/1563                   Loss Discriminator: 0.412, loss Generator: 1.433
# Fretchet Distance:  263.43984723127767
# Epoch [24/50] Batch 0/1563                   Loss Discriminator: 0.409, loss Generator: 1.337
# Epoch [24/50] Batch 1000/1563                   Loss Discriminator: 0.519, loss Generator: 1.545
# Fretchet Distance:  278.45682874431327
# Epoch [25/50] Batch 0/1563                   Loss Discriminator: 0.576, loss Generator: 1.660
# Epoch [25/50] Batch 1000/1563                   Loss Discriminator: 0.432, loss Generator: 1.506
# Fretchet Distance:  250.28456945018954
# Epoch [26/50] Batch 0/1563                   Loss Discriminator: 0.409, loss Generator: 1.555
# Epoch [26/50] Batch 1000/1563                   Loss Discriminator: 0.434, loss Generator: 1.952
# Fretchet Distance:  260.91083154092246
# Epoch [27/50] Batch 0/1563                   Loss Discriminator: 0.449, loss Generator: 1.397
# Epoch [27/50] Batch 1000/1563                   Loss Discriminator: 0.416, loss Generator: 1.553
# Fretchet Distance:  252.48094501308054
# Epoch [28/50] Batch 0/1563                   Loss Discriminator: 0.439, loss Generator: 1.441
# Epoch [28/50] Batch 1000/1563                   Loss Discriminator: 0.337, loss Generator: 1.778
# Fretchet Distance:  264.5451897146285
# Epoch [29/50] Batch 0/1563                   Loss Discriminator: 0.449, loss Generator: 2.048
# Epoch [29/50] Batch 1000/1563                   Loss Discriminator: 0.363, loss Generator: 2.100
# Fretchet Distance:  263.1020886084235
# Epoch [30/50] Batch 0/1563                   Loss Discriminator: 0.449, loss Generator: 1.836
# Epoch [30/50] Batch 1000/1563                   Loss Discriminator: 0.577, loss Generator: 1.805
# Fretchet Distance:  250.27040145265124
# Epoch [31/50] Batch 0/1563                   Loss Discriminator: 0.342, loss Generator: 1.902
# Epoch [31/50] Batch 1000/1563                   Loss Discriminator: 0.421, loss Generator: 1.711
# Fretchet Distance:  266.59643938906095
# Epoch [32/50] Batch 0/1563                   Loss Discriminator: 0.343, loss Generator: 2.391
# Epoch [32/50] Batch 1000/1563                   Loss Discriminator: 0.367, loss Generator: 2.176
# Fretchet Distance:  246.99443801838748
# Epoch [33/50] Batch 0/1563                   Loss Discriminator: 0.396, loss Generator: 2.244
# Epoch [33/50] Batch 1000/1563                   Loss Discriminator: 0.289, loss Generator: 1.999
# Fretchet Distance:  266.59818387357325
# Epoch [34/50] Batch 0/1563                   Loss Discriminator: 0.243, loss Generator: 2.047
# Epoch [34/50] Batch 1000/1563                   Loss Discriminator: 0.340, loss Generator: 2.242
# Fretchet Distance:  266.20535679078586
# Epoch [35/50] Batch 0/1563                   Loss Discriminator: 0.257, loss Generator: 2.411
# Epoch [35/50] Batch 1000/1563                   Loss Discriminator: 0.301, loss Generator: 2.889
# Fretchet Distance:  268.4035714044628
# Epoch [36/50] Batch 0/1563                   Loss Discriminator: 0.289, loss Generator: 2.581
# Epoch [36/50] Batch 1000/1563                   Loss Discriminator: 0.276, loss Generator: 2.556
# Fretchet Distance:  256.89788998611925
# Epoch [37/50] Batch 0/1563                   Loss Discriminator: 0.255, loss Generator: 2.501
# Epoch [37/50] Batch 1000/1563                   Loss Discriminator: 0.316, loss Generator: 2.731
# Fretchet Distance:  266.18470212776504
# Epoch [38/50] Batch 0/1563                   Loss Discriminator: 0.211, loss Generator: 3.030
# Epoch [38/50] Batch 1000/1563                   Loss Discriminator: 0.348, loss Generator: 2.070
# Fretchet Distance:  271.29899078332403
# Epoch [39/50] Batch 0/1563                   Loss Discriminator: 0.269, loss Generator: 4.233
# Epoch [39/50] Batch 1000/1563                   Loss Discriminator: 0.281, loss Generator: 2.761
# Fretchet Distance:  302.2997464929702
# Epoch [40/50] Batch 0/1563                   Loss Discriminator: 0.257, loss Generator: 2.768
# Epoch [40/50] Batch 1000/1563                   Loss Discriminator: 0.337, loss Generator: 2.854
# Fretchet Distance:  256.5936316049008
# Epoch [41/50] Batch 0/1563                   Loss Discriminator: 0.138, loss Generator: 3.464
# Epoch [41/50] Batch 1000/1563                   Loss Discriminator: 0.229, loss Generator: 2.891
# Fretchet Distance:  263.6044562066045
# Epoch [42/50] Batch 0/1563                   Loss Discriminator: 0.164, loss Generator: 2.963
# Epoch [42/50] Batch 1000/1563                   Loss Discriminator: 0.154, loss Generator: 3.179
# Fretchet Distance:  262.9518915194538
# Epoch [43/50] Batch 0/1563                   Loss Discriminator: 0.190, loss Generator: 3.241
# Epoch [43/50] Batch 1000/1563                   Loss Discriminator: 0.192, loss Generator: 2.915
# Fretchet Distance:  270.1730980496356
# Epoch [44/50] Batch 0/1563                   Loss Discriminator: 0.171, loss Generator: 3.758
# Epoch [44/50] Batch 1000/1563                   Loss Discriminator: 0.220, loss Generator: 2.816
# Fretchet Distance:  259.34027536012206
# Epoch [45/50] Batch 0/1563                   Loss Discriminator: 0.138, loss Generator: 3.542
# Epoch [45/50] Batch 1000/1563                   Loss Discriminator: 0.186, loss Generator: 3.170
# Fretchet Distance:  309.6377918412743
# Epoch [46/50] Batch 0/1563                   Loss Discriminator: 0.206, loss Generator: 3.227
# Epoch [46/50] Batch 1000/1563                   Loss Discriminator: 0.187, loss Generator: 3.088
# Fretchet Distance:  248.46457149606357
# Epoch [47/50] Batch 0/1563                   Loss Discriminator: 0.182, loss Generator: 3.632
# Epoch [47/50] Batch 1000/1563                   Loss Discriminator: 0.092, loss Generator: 3.953
# Fretchet Distance:  281.67986558700386
# Epoch [48/50] Batch 0/1563                   Loss Discriminator: 0.238, loss Generator: 3.145
# Epoch [48/50] Batch 1000/1563                   Loss Discriminator: 0.157, loss Generator: 4.234
# Fretchet Distance:  279.4173224362119
# Epoch [49/50] Batch 0/1563                   Loss Discriminator: 0.101, loss Generator: 4.467
# Epoch [49/50] Batch 1000/1563                   Loss Discriminator: 0.310, loss Generator: 4.916
# Fretchet Distance:  266.56852065797744
# Epoch [50/50] Batch 0/1563                   Loss Discriminator: 0.103, loss Generator: 4.606
# Epoch [50/50] Batch 1000/1563                   Loss Discriminator: 0.204, loss Generator: 4.775
# Fretchet Distance:  285.86103083526376
# elapsed time：1555.65 s.

# %%
plt.figure(figsize=(10,5))
plt.title("Generator and Discriminator Loss During Training")
plt.plot(gen_loss,label="Gen")
plt.plot(disc_loss,label="Disc")
plt.xlabel("iterations")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,15))
plt.subplot(1,2,1)
plt.axis("off")
plt.title("Real Images")
plt.imshow(np.transpose(utils.make_grid(real_batch[0].to(device)[:64], padding=5, normalize=True).cpu(),(1,2,0)))

plt.subplot(1,2,2)
plt.axis("off")
plt.title("Fake Images")
plt.imshow(np.transpose(img_list[-1],(1,2,0)))
plt.savefig('compare.png')
plt.show()
